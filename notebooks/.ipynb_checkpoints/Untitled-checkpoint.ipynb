# %%
from ncei_es60 import nav_checker as nc

# %%
cruise_raw_directory = "../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files"
cruise_processed_directory = "../CRUISES_processed/EBS_2017_AlaskaKnight_leg_4"

# %%
# Run in read-only mode (no file movement, just to check)
nc.READ_ONLY_MODE = True

# Check for NMEA string
nc.USE_SENTENCE_FOR_NAV = True

# %%
summary_df = nc.main(cruise_raw_directory)
# Out:
# READ ONLY MODE: No directories will be created and no files or folders will be moved or copied.
# READ ONLY: ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/.DS_Store -> ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/other/.DS_Store
# ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/.DS_Store -> other
# READ ONLY: ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/L0384-D20170810-T182653-ES60.out -> ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/other/L0384-D20170810-T182653-ES60.out
# ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/L0384-D20170810-T182653-ES60.out -> other
# READ ONLY: ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/L0385-D20170811-T075018-ES60.out -> ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/other/L0385-D20170811-T075018-ES60.out
# ../CRUISES_raw/EBS_2017_AlaskaKnight/leg 4 raw files/L0385-D20170811-T075018-ES60.out -> other
# ...

# %%
print(summary_df.head())
# Out:
#                                file  usable_nav nav_decision_basis  has_lat  \
# 0  L0384-D20170810-T182653-ES60.raw        True    latlon+sentence     True
# 1  L0384-D20170810-T185504-ES60.raw        True    latlon+sentence     True
# 2  L0384-D20170810-T192316-ES60.raw        True    latlon+sentence     True
# 3  L0384-D20170810-T195127-ES60.raw        True    latlon+sentence     True
# 4  L0384-D20170810-T201939-ES60.raw        True    latlon+sentence     True
#
#    has_lon  has_latlon  lat_non_nan_count  lon_non_nan_count  has_sentence  \
# 0     True        True               5076               5076          True
# 1     True        True               5073               5073          True
# 2     True        True               5076               5076          True
# 3     True        True               5073               5073          True
# 4     True        True               5076               5076          True
#
#    n_time1  use_sentence_for_nav error
# ...
