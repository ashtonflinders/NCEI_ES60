# %%
from pathlib import Path
from ncei_es60.depth_extractor import DepthExtractionConfig, process_cruise

# %%
cruise_processed_directory = "../CRUISES_processed/EBS17VA_example"

# %%
config = DepthExtractionConfig(
    cruise_dir=Path("../CRUISES_processed/EBS17VA_example"),
    single_raw_file=None,  # Use None for all *.raw files in raw_w_nav.
    output_subdir_name="depth",
    image_subdir_name="images",
    run_blackwell_detector=False,
    save_depth_images=True,
    show_plots = False
)

# %%
summary_df = process_cruise(config)
# Out:
# Found 6 raw file(s) to process.
# Raw input directory: ../CRUISES_processed/EBS17VA_example/raw_w_nav
# CSV output directory: ../CRUISES_processed/EBS17VA_example/depth
# Image output directory: ../CRUISES_processed/EBS17VA_example/images
# Error log: ../CRUISES_processed/EBS17VA_example/depth_processing_errors.txt
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170602-T224458-ES60.raw
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170602-T224458-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170602-T224458-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170602-T224458-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170602-T224458-ES60.raw
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170602-T232902-ES60.raw
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170602-T232902-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170602-T232902-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170602-T232902-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170602-T232902-ES60.raw
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170603-T001306-ES60.raw
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170603-T001306-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T001306-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T001306-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170603-T001306-ES60.raw
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170603-T005710-ES60.raw
# /Users/aflinders/Library/CloudStorage/OneDrive-DOI/NOAA_NCEI_ES60/echopype/echopype/convert/set_groups_ek60.py:710: FutureWarning: In a future version of xarray the default value for join will change from join='outer' to join='exact'. This change will result in the following ValueError: cannot be aligned with join='exact' because index/labels/sizes are not equal along these coordinates (dimensions): 'range_sample' ('range_sample',) The recommendation is to set join explicitly for this case.
#   [ds, xr.concat(ds_backscatter, dim="channel")], combine_attrs="override"
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170603-T005710-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T005710-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T005710-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170603-T005710-ES60.raw
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170603-T014114-ES60.raw
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170603-T014114-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T014114-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T014114-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170603-T014114-ES60.raw
#
# ================================================================================
# Processing raw file: ../CRUISES_processed/EBS17VA_example/raw_w_nav/L0004-D20170603-T022518-ES60.raw
# Available channels:
#   GPT  38 kHz 00907207b7d4 1 ES38B
#   GPT 120 kHz 0090720649dc 2 120-25
# Split-beam angle variables found.
#
# Running bottom detection for: GPT  38 kHz 00907207b7d4 1 ES38B
#
# Running bottom detection for: GPT 120 kHz 0090720649dc 2 120-25
# Navigation variables found.
# latitude dims: ('ping_time',)
# longitude dims: ('ping_time',)
# Saved combined bottom-depth CSV to: ../CRUISES_processed/EBS17VA_example/depth/L0004-D20170603-T022518-ES60_depth.csv
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T022518-ES60_38kHz_bottom_detection.png
# Saved depth QC image to: ../CRUISES_processed/EBS17VA_example/images/L0004-D20170603-T022518-ES60_120kHz_bottom_detection.png
# Finished processing: L0004-D20170603-T022518-ES60.raw
#
# ================================================================================
# Processing complete.
# Successful files: 6
# Failed files:     0

# %%
print("\nSummary table:")
print(summary_df)
# Out:
# Summary table:
#                                file  \
# 0  L0004-D20170602-T224458-ES60.raw
# 1  L0004-D20170602-T232902-ES60.raw
# 2  L0004-D20170603-T001306-ES60.raw
# 3  L0004-D20170603-T005710-ES60.raw
# 4  L0004-D20170603-T014114-ES60.raw
# 5  L0004-D20170603-T022518-ES60.raw
#
#                                          source_path  success  \
# 0  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
# 1  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
# 2  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
# 3  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
# 4  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
# 5  ../CRUISES_processed/EBS17VA_example/raw_w_nav...     True
#
#                                             csv_path  image_count  \
# 0  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
# 1  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
# 2  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
# 3  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
# 4  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
# 5  ../CRUISES_processed/EBS17VA_example/depth/L00...            2
#
#                                          image_paths  n_channels  \
# 0  ../CRUISES_processed/EBS17VA_example/images/L0...           2
# 1  ../CRUISES_processed/EBS17VA_example/images/L0...           2
# 2  ../CRUISES_processed/EBS17VA_example/images/L0...           2
# 3  ../CRUISES_processed/EBS17VA_example/images/L0...           2
# 4  ../CRUISES_processed/EBS17VA_example/images/L0...           2
# 5  ../CRUISES_processed/EBS17VA_example/images/L0...           2
#
#                                             channels  has_splitbeam_angles  \
# 0  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
# 1  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
# 2  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
# 3  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
# 4  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
# 5  GPT  38 kHz 00907207b7d4 1 ES38B;GPT 120 kHz 0...                  True
#
#    run_blackwell_detector error
# 0                   False
# 1                   False
# 2                   False
# 3                   False
# 4                   False
# 5                   False
