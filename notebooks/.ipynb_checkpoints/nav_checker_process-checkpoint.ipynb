# %%
from ncei_es60 import nav_checker as nc

# %%
cruise_raw_directory = "../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60"
cruise_processed_directory = "../CRUISES_processed/EBS17VA_WCSD"

# %%
# Run in read-only mode (no file movement, just to check)
nc.READ_ONLY_MODE = False

# Don't move file, copy to output directory
nc.MOVE_FILES = False
nc.OUTPUT_DIR = cruise_processed_directory

# Check for NMEA string
nc.USE_SENTENCE_FOR_NAV = True

# %%
summary_df = nc.main(cruise_raw_directory)
# Out:
# Created output directory: ../CRUISES_processed/EBS17VA_WCSD
# Source directory: ../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60
# Destination directory: ../CRUISES_processed/EBS17VA_WCSD
# MOVE_FILES: False
# CREATE_OUTPUT_DIR: True
# ../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60/.DS_Store -> ../CRUISES_processed/EBS17VA_WCSD/other/.DS_Store
# ../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60/L0004-D20170602-T224458-ES60.out -> ../CRUISES_processed/EBS17VA_WCSD/other/L0004-D20170602-T224458-ES60.out
# ../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60/L0005-D20170603-T160227-ES60.out -> ../CRUISES_processed/EBS17VA_WCSD/other/L0005-D20170603-T160227-ES60.out
# ../CRUISES_raw/EBS17VA/EBS17VA/data/EBS17VA_WCSD_ES60/data/ES60/L0006-D20170603-T171021-ES60.out -> ../CRUISES_processed/EBS17VA_WCSD/other/L0006-D20170603-T171021-ES60.out
# ...

# %%
print(summary_df.head())
# Out:
#                                file  \
# 0  L0004-D20170602-T224458-ES60.raw
# 1  L0004-D20170602-T232902-ES60.raw
# 2  L0004-D20170603-T001306-ES60.raw
# 3  L0004-D20170603-T005710-ES60.raw
# 4  L0004-D20170603-T014114-ES60.raw
#
#                                          source_path  usable_nav  \
# 0  /Users/aflinders/Library/CloudStorage/OneDrive...        True
# 1  /Users/aflinders/Library/CloudStorage/OneDrive...        True
# 2  /Users/aflinders/Library/CloudStorage/OneDrive...        True
# 3  /Users/aflinders/Library/CloudStorage/OneDrive...        True
# 4  /Users/aflinders/Library/CloudStorage/OneDrive...        True
#
#   nav_decision_basis  has_lat  has_lon  has_latlon  lat_non_nan_count  \
# 0    latlon+sentence     True     True        True               7932
# 1    latlon+sentence     True     True        True               7932
# 2    latlon+sentence     True     True        True               7932
# ...
